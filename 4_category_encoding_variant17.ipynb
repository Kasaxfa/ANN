# %% [markdown]
# # Лабораторная работа №4 — вариант 17
# ## Кодирование категорий и отчёт по курсовой работе
#
# Ноутбук запускает воспроизводимый расчёт из `lab4_solution.py` и показывает итоговые метрики.

# %%
from pathlib import Path
import json

# Полный эксперимент: обучение, 72 кодировки, Excel и визуализации.
# %run lab4_solution.py --data Daily_Water_Intake.csv --output-dir .

# %%
metrics = json.loads(Path('metrics.json').read_text(encoding='utf-8'))
print('Baseline errors:', metrics['baseline']['confusion_matrix'][0][1] + metrics['baseline']['confusion_matrix'][1][0])
print('Best errors:', metrics['best_encoding']['errors'])
print('Best encoding:', metrics['best_encoding']['mapping'])
